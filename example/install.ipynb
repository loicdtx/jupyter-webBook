# %% [markdown]
# # Installation

# %% [markdown]
# ## Dependencies
#
# - pandoc
#
# `sudo apt-get install pandoc`
#
# - development version of `nbconvert`
#
# `pip install git+https://github.com/jupyter/nbconvert.git`
#
# ## Installation with pip
#
# `pip install git+https://github.com/loicdtx/python-webbook.git`
